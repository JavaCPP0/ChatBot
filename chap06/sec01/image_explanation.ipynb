# %%
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode("utf-8")
    return encoded_string

bread1 = "../data/bread.jpg"
bread2 = "../data/bread2.jpg"
encoded_image1 = encode_image(bread1)
encoded_image2 = encode_image(bread2)

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

messages=[
    {"role": "user", "content": [{"type": "text", "text": "두 빵의 차이에 대해 설명하세요."},
                                 {"type": "image_url", "image_url": {"url": f"data:image/jepg;base64,{encoded_image1}"},},
                                 {"type": "image_url", "image_url": {"url": f"data:image/jepg;base64,{encoded_image2}"},}],}
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages,
)

response.choices[0].message.content
# Out:
# '두 이미지에 있는 빵의 차이점은 다음과 같습니다:\n\n1. 재료 및 스타일:\n   - 첫 번째 이미지: 흰 식빵으로, 부드럽고 촉촉하며 주로 정제된 밀가루로 만들어집니다. 주로 토스트나 샌드위치에 사용됩니다.\n   - 두 번째 이미지: 곡물이나 씨앗이 포함된 통곡물 빵입니다. 질감이 좀 더 거칠고 고소한 맛이 특징입니다. 건강을 고려한 선택으로 많이 먹습니다.\n\n2. 외관:\n   - 첫 번째 이미지: 사각형 모양으로 일정하게 잘려 있어서 규칙적인 형태를 가지고 있습니다.\n   - 두 번째 이미지: 둥글고 불규칙한 모양이며, 외부에 곡물과 씨앗이 있어 시각적으로 다양합니다.\n\n3. 질감:\n   - 첫 번째 이미지: 부드럽고 촉촉하며 탄력이 있는 질감입니다.\n   - 두 번째 이미지: 더 단단하고 씹는 맛이 있으며, 바삭한 외부 질감을 가지고 있습니다.\n\n4. 영양 성분:\n   - 두 번째 이미지의 통곡물 빵은 식이섬유와 영양소가 더 풍부할 수 있습니다.'
